# %%
import ROOT
import numpy as np
import matplotlib.pyplot as plt
import sys
import os

N_Threads = "10"

# %%
def make_histo(Data_array,Title,nbins,xmin,xmax,save=True):
    Histo = ROOT.TH1F(Title,Title,nbins,xmin,xmax)
    for value in Data_array:
        Histo.Fill(value)

    Canv=ROOT.TCanvas()
    Histo.Draw()
    
    if save:
        Image_name=Title + '_Histo.pdf'
        Canv.Print(Image_name)
    
    return Histo, Canv

# %%
#name='gold_47_SC_90m_211220'
#name.split('_')
#
#angle=int(name.split('_')[1])*(1 if name.split('_')[2]=='DC' else -1)
#
#file=open('gold_47_SC_90m_211220/Stat_gold_47_SC_90m_211220.txt')
#line=file.readlines()
#for l in line:
#    if (l.startswith("Readout_time")):
#        time=float(l.split('=')[1].strip()[:-1])
#    if (l.startswith("Strobe")):
#        Strobe=int(l.split('=')[1].strip()[:-1])
#    if (l.startswith("Gap")):
#        Gap=int(l.split('=')[1].strip()[:-1])
#        
#weight=3600*(Gap+Strobe)/(Strobe*time)
#
#os.system("python Packet_analyzer.py -f gold_47_SC_90m_211220 -p -A DB -d 1 10 -b 1000 -s %i -w %f " % (angle,weight))

# %% [markdown]
# # Analysis on a specific dataset

# %%
files=os.listdir('Data/')
for name in files:
    if name.startswith("gold_11"):
        angle=int(name.split('_')[1])*(1 if name.split('_')[2]=='DC' else -1)

        file=open("Data/"+name+"/Stat_"+name+".txt")
        line=file.readlines()
        for l in line:
            if (l.startswith("Readout_time")):
                time=float(l.split('=')[1].strip()[:-1])
            if (l.startswith("Strobe")):
                Strobe=int(l.split('=')[1].strip()[:-1])
            if (l.startswith("Gap")):
                Gap=int(l.split('=')[1].strip()[:-1])
                
        #weight that gives count/hour
        weight=3600*(Gap+Strobe)/(Strobe*time)

        os.system("python Packet_analyzer.py -Df Data -f " + name + " -p -A DB -d 1 10 -b 1000 -NThr " + N_Threads + " -s %i -w %f " % (angle,weight))
# Out:
# ERROR in cling::CIFactory::createCI(): cannot extract standard library include paths!
# Invoking:
#   LC_ALL=C x86_64-conda-linux-gnu-c++  -O3 -DNDEBUG -xc++ -E -v /dev/null 2>&1 | sed -n -e '/^.include/,${' -e '/^ \/.*++/p' -e '}'
# Results was:
# With exit code 0
# gold_11_SC_150m_221220: 100%|██████████| 1/1 [00:00<00:00,  1.87it/s]

# %%
! $ROOTSYS/bin/hadd Tot_63_2.root Analyzed_Data/gold_*/*.root
# Out:
# ERROR in cling::CIFactory::createCI(): cannot extract standard library include paths!
# Invoking:
#   LC_ALL=C x86_64-conda-linux-gnu-c++  -O3 -DNDEBUG -xc++ -E -v /dev/null 2>&1 | sed -n -e '/^.include/,${' -e '/^ \/.*++/p' -e '}'
# Results was:
# With exit code 0
# hadd Target file: Tot_63_2.root
# hadd compression setting for all output: 1
# hadd Source file 1: Analyzed_Data/gold_11_SC_150m_221220/gold_11_SC_150m_221220.root
# hadd Source file 2: Analyzed_Data/gold_13_SC_60m_221220/gold_13_SC_60m_221220.root
# hadd Source file 3: Analyzed_Data/gold_15_SC_90m_221220/gold_15_SC_90m_221220.root
# hadd Source file 4: Analyzed_Data/gold_17_DC_30m_run1_251220/gold_17_DC_30m_run1_251220.root
# hadd Source file 5: Analyzed_Data/gold_17_DC_30m_run2_251220/gold_17_DC_30m_run2_251220.root
# hadd Source file 6: Analyzed_Data/gold_17_DC_30m_run3_251220/gold_17_DC_30m_run3_251220.root
# hadd Source file 7: Analyzed_Data/gold_17_DC_30m_run4_251220/gold_17_DC_30m_run4_251220.root
# hadd Source file 8: Analyzed_Data/gold_17_DC_30m_run5_251220/gold_17_DC_30m_run5_251220.root
# hadd Source file 9: Analyzed_Data/gold_17_DC_30m_run6_251220/gold_17_DC_30m_run6_251220.root
# hadd Source file 10: Analyzed_Data/gold_17_SC_90m_221220/gold_17_SC_90m_221220.root
# hadd Source file 11: Analyzed_Data/gold_19_SC_90m_221220/gold_19_SC_90m_221220.root
# hadd Source file 12: Analyzed_Data/gold_21_SC_60m_221220/gold_21_SC_60m_221220.root
# hadd Source file 13: Analyzed_Data/gold_27_DC_30m_run10_231220/gold_27_DC_30m_run10_231220.root
# hadd Source file 14: Analyzed_Data/gold_27_DC_30m_run11_231220/gold_27_DC_30m_run11_231220.root
# hadd Source file 15: Analyzed_Data/gold_27_DC_30m_run1_231220/gold_27_DC_30m_run1_231220.root
# hadd Source file 16: Analyzed_Data/gold_27_DC_30m_run2_231220/gold_27_DC_30m_run2_231220.root
# hadd Source file 17: Analyzed_Data/gold_27_DC_30m_run3_231220/gold_27_DC_30m_run3_231220.root
# hadd Source file 18: Analyzed_Data/gold_27_DC_30m_run4_231220/gold_27_DC_30m_run4_231220.root
# hadd Source file 19: Analyzed_Data/gold_27_DC_30m_run5_231220/gold_27_DC_30m_run5_231220.root
# hadd Source file 20: Analyzed_Data/gold_27_DC_30m_run6_231220/gold_27_DC_30m_run6_231220.root
# hadd Source file 21: Analyzed_Data/gold_27_DC_30m_run7_231220/gold_27_DC_30m_run7_231220.root
# hadd Source file 22: Analyzed_Data/gold_27_DC_30m_run8_231220/gold_27_DC_30m_run8_231220.root
# hadd Source file 23: Analyzed_Data/gold_27_DC_30m_run9_231220/gold_27_DC_30m_run9_231220.root
# hadd Source file 24: Analyzed_Data/gold_3_SC_60m_231220/gold_3_SC_60m_231220.root
# hadd Source file 25: Analyzed_Data/gold_45_SC_90m_211220/gold_45_SC_90m_211220.root
# hadd Source file 26: Analyzed_Data/gold_47_SC_90m_211220/gold_47_SC_90m_211220.root
# hadd Source file 27: Analyzed_Data/gold_49_SC_90m_211220/gold_49_SC_90m_211220.root
# hadd Source file 28: Analyzed_Data/gold_51_SC_90m_211220/gold_51_SC_90m_211220.root
# hadd Source file 29: Analyzed_Data/gold_53_SC_90m_211220/gold_53_SC_90m_211220.root
# hadd Source file 30: Analyzed_Data/gold_59_SC_240m_201220/gold_59_SC_240m_201220.root
# hadd Source file 31: Analyzed_Data/gold_5_SC_150m_231220/gold_5_SC_150m_231220.root
# hadd Source file 32: Analyzed_Data/gold_61_SC_240m_201220/gold_61_SC_240m_201220.root
# hadd Source file 33: Analyzed_Data/gold_63_SC_90m_201220/gold_63_SC_90m_201220.root
# hadd Source file 34: Analyzed_Data/gold_7_DC_30m_run1_271220/gold_7_DC_30m_run1_271220.root
# hadd Source file 35: Analyzed_Data/gold_7_DC_30m_run2_271220/gold_7_DC_30m_run2_271220.root
# hadd Source file 36: Analyzed_Data/gold_7_DC_30m_run3_271220/gold_7_DC_30m_run3_271220.root
# hadd Source file 37: Analyzed_Data/gold_7_DC_30m_run4_271220/gold_7_DC_30m_run4_271220.root
# hadd Source file 38: Analyzed_Data/gold_7_SC_240m_231220/gold_7_SC_240m_231220.root
# hadd Source file 39: Analyzed_Data/gold_9_SC_150m_221220/gold_9_SC_150m_221220.root
# hadd Target path: Tot_63_2.root:/

# %% [markdown]
# # Analysis with normalization (time and Strobe parameters)

# %%
#normalization array from -180° to 180° [steps]
ALPIDE_norm=np.zeros(201)
Data_folder="Data"

Run_Analysis = True

#load files of a cartain dataset
files=os.listdir(Data_folder + "/")
for name in files:
    if name.startswith("gold_alpide"):
        #for gold_ files
        #angle=int(name.split('_')[1])*(1 if name.split('_')[2]=='DC' else -1)
        # for gold_alpide files
        angle=int(name.split('_')[2])*(1 if name.split('_')[3]=='DC' else -1)
        file=open(Data_folder+"/"+name+"/Stat_"+name+".txt")
        line=file.readlines()
        for l in line:
            if (l.startswith("Readout_time")):
                time=float(l.split('=')[1].strip()[:-1])
            if (l.startswith("Strobe")):
                Strobe=int(l.split('=')[1].strip()[:-1])
            if (l.startswith("Gap")):
                Gap=int(l.split('=')[1].strip()[:-1])
                
        #weight that gives effective exposition time [hours]
        weight=3600*(Gap+Strobe)/(Strobe*time)
        
        #compute the normalization parameter
        for i in range(angle-29,angle-4):
            ALPIDE_norm[100+i] += 1/weight

        #analyze the data
        #os.system("python Packet_analyzer.py -f " + name + " -p -b 1000 -s %i -w %f" % (angle,weight))
        if Run_Analysis:
            Args = "-Df "+Data_folder+" -f "+name+" -p -A DB -NThr "+N_Threads+" -b 1000 -s %i -w %f "%(angle,weight)
            # %run 'Packet_analyzer.py' {Args}
# Out:
# gold_alpide_23_SC_120m_run2_070121: 100%|██████████| 1/1 [00:00<00:00,  2.47it/s]
# gold_alpide_43_SC_240m_run11_040121: 100%|██████████| 1/1 [00:00<00:00,  1.79it/s]
# gold_alpide_33_SC_120m_run9_060121: 100%|██████████| 1/1 [00:00<00:00,  2.62it/s]
# gold_alpide_23_SC_120m_run1_070121: 100%|██████████| 1/1 [00:00<00:00,  2.11it/s]
# gold_alpide_23_SC_120m_run5_070121: 100%|██████████| 1/1 [00:00<00:00,  2.25it/s]
# gold_alpide_23_SC_120m_run3_070121: 100%|██████████| 1/1 [00:00<00:00,  2.07it/s]
# gold_alpide_23_SC_120m_run8_070121: 100%|██████████| 1/1 [00:00<00:00,  2.36it/s]
# gold_alpide_33_SC_120m_run7_060121: 100%|██████████| 1/1 [00:00<00:00,  2.23it/s]
# gold_alpide_53_SC_240m_run6_020121: 100%|██████████| 1/1 [00:00<00:00,  1.80it/s]
# gold_alpide_23_SC_120m_run9_070121: 100%|██████████| 1/1 [00:00<00:00,  2.34it/s]
# gold_alpide_53_SC_240m_run9_020121: 100%|██████████| 1/1 [00:00<00:00,  1.79it/s]
# gold_alpide_43_SC_240m_run4_040121: 100%|██████████| 1/1 [00:00<00:00,  1.74it/s]
# gold_alpide_23_SC_120m_run6_070121: 100%|██████████| 1/1 [00:00<00:00,  2.27it/s]
# gold_alpide_43_SC_240m_run6_040121: 100%|██████████| 1/1 [00:00<00:00,  1.71it/s]
# gold_alpide_43_SC_240m_run3_040121: 100%|██████████| 1/1 [00:00<00:00,  1.71it/s]
# gold_alpide_43_SC_240m_run5_040121: 100%|██████████| 1/1 [00:00<00:00,  1.77it/s]
# gold_alpide_53_SC_240m_run1_020121: 100%|██████████| 1/1 [00:00<00:00,  1.77it/s]
# gold_alpide_53_SC_240m_run10_020121: 100%|██████████| 1/1 [00:00<00:00,  1.87it/s]
# gold_alpide_43_SC_240m_run10_040121: 100%|██████████| 1/1 [00:00<00:00,  1.87it/s]
# gold_alpide_33_SC_120m_run10_060121: 100%|██████████| 1/1 [00:00<00:00,  2.22it/s]
# gold_alpide_33_SC_120m_run1_060121: 100%|██████████| 1/1 [00:00<00:00,  2.33it/s]
# gold_alpide_33_SC_120m_run2_060121: 100%|██████████| 1/1 [00:00<00:00,  2.32it/s]
# gold_alpide_23_SC_120m_run11_070121: 100%|██████████| 1/1 [00:00<00:00,  2.15it/s]
# gold_alpide_53_SC_240m_run4_020121: 100%|██████████| 1/1 [00:00<00:00,  1.69it/s]
# gold_alpide_53_SC_240m_run12_020121: 100%|██████████| 1/1 [00:00<00:00,  1.79it/s]
# gold_alpide_43_SC_240m_run9_040121: 100%|██████████| 1/1 [00:00<00:00,  1.32it/s]
# gold_alpide_53_SC_240m_run3_020121: 100%|██████████| 1/1 [00:00<00:00,  1.86it/s]
# gold_alpide_23_SC_120m_run10_070121: 100%|██████████| 1/1 [00:00<00:00,  2.24it/s]
# gold_alpide_43_SC_240m_run1_040121: 100%|██████████| 1/1 [00:00<00:00,  1.33it/s]
# gold_alpide_23_SC_120m_run12_070121: 100%|██████████| 1/1 [00:00<00:00,  2.26it/s]
# gold_alpide_33_SC_120m_run4_060121: 100%|██████████| 1/1 [00:00<00:00,  2.25it/s]
# gold_alpide_43_SC_240m_run2_040121: 100%|██████████| 1/1 [00:00<00:00,  1.79it/s]
# gold_alpide_23_SC_120m_run7_070121: 100%|██████████| 1/1 [00:00<00:00,  2.14it/s]
# gold_alpide_33_SC_120m_run6_060121: 100%|██████████| 1/1 [00:00<00:00,  2.14it/s]
# gold_alpide_53_SC_240m_run11_020121: 100%|██████████| 1/1 [00:00<00:00,  1.54it/s]
# gold_alpide_53_SC_240m_run2_020121: 100%|██████████| 1/1 [00:00<00:00,  1.61it/s]
# gold_alpide_43_SC_240m_run8_040121: 100%|██████████| 1/1 [00:00<00:00,  1.73it/s]
# gold_alpide_33_SC_120m_run12_060121: 100%|██████████| 1/1 [00:00<00:00,  2.22it/s]
# gold_alpide_33_SC_120m_run3_060121: 100%|██████████| 1/1 [00:00<00:00,  2.24it/s]
# gold_alpide_33_SC_120m_run11_060121: 100%|██████████| 1/1 [00:00<00:00,  2.23it/s]
# gold_alpide_33_SC_120m_run8_060121: 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
# gold_alpide_33_SC_120m_run5_060121: 100%|██████████| 1/1 [00:00<00:00,  2.11it/s]
# gold_alpide_43_SC_240m_run7_040121: 100%|██████████| 1/1 [00:00<00:00,  1.70it/s]
# gold_alpide_53_SC_240m_run7_020121: 100%|██████████| 1/1 [00:00<00:00,  1.67it/s]
# gold_alpide_23_SC_120m_run4_070121: 100%|██████████| 1/1 [00:00<00:00,  2.11it/s]
# gold_alpide_43_SC_240m_run12_040121: 100%|██████████| 1/1 [00:00<00:00,  1.17it/s]
# gold_alpide_53_SC_240m_run8_020121: 100%|██████████| 1/1 [00:00<00:00,  1.62it/s]
# gold_alpide_53_SC_240m_run5_020121: 100%|██████████| 1/1 [00:00<00:00,  1.74it/s]

# %%
#merge all the TTree
! $ROOTSYS/bin/hadd -f Tot_data_tree/Tot_Alide_53SC_23SC.root Analyzed_Data/gold_alpide*/*.root
# Out:
# ERROR in cling::CIFactory::createCI(): cannot extract standard library include paths!
# Invoking:
#   LC_ALL=C x86_64-conda-linux-gnu-c++  -O3 -DNDEBUG -xc++ -E -v /dev/null 2>&1 | sed -n -e '/^.include/,${' -e '/^ \/.*++/p' -e '}'
# Results was:
# With exit code 0
# hadd Target file: Tot_data_tree/Tot_Alide_53SC_23SC.root
# hadd compression setting for all output: 1
# hadd Source file 1: Analyzed_Data/gold_alpide_23_SC_120m_run10_070121/gold_alpide_23_SC_120m_run10_070121.root
# hadd Source file 2: Analyzed_Data/gold_alpide_23_SC_120m_run1_070121/gold_alpide_23_SC_120m_run1_070121.root
# hadd Source file 3: Analyzed_Data/gold_alpide_23_SC_120m_run11_070121/gold_alpide_23_SC_120m_run11_070121.root
# hadd Source file 4: Analyzed_Data/gold_alpide_23_SC_120m_run12_070121/gold_alpide_23_SC_120m_run12_070121.root
# hadd Source file 5: Analyzed_Data/gold_alpide_23_SC_120m_run2_070121/gold_alpide_23_SC_120m_run2_070121.root
# hadd Source file 6: Analyzed_Data/gold_alpide_23_SC_120m_run3_070121/gold_alpide_23_SC_120m_run3_070121.root
# hadd Source file 7: Analyzed_Data/gold_alpide_23_SC_120m_run4_070121/gold_alpide_23_SC_120m_run4_070121.root
# hadd Source file 8: Analyzed_Data/gold_alpide_23_SC_120m_run5_070121/gold_alpide_23_SC_120m_run5_070121.root
# hadd Source file 9: Analyzed_Data/gold_alpide_23_SC_120m_run6_070121/gold_alpide_23_SC_120m_run6_070121.root
# hadd Source file 10: Analyzed_Data/gold_alpide_23_SC_120m_run7_070121/gold_alpide_23_SC_120m_run7_070121.root
# hadd Source file 11: Analyzed_Data/gold_alpide_23_SC_120m_run8_070121/gold_alpide_23_SC_120m_run8_070121.root
# hadd Source file 12: Analyzed_Data/gold_alpide_23_SC_120m_run9_070121/gold_alpide_23_SC_120m_run9_070121.root
# hadd Source file 13: Analyzed_Data/gold_alpide_33_SC_120m_run10_060121/gold_alpide_33_SC_120m_run10_060121.root
# hadd Source file 14: Analyzed_Data/gold_alpide_33_SC_120m_run1_060121/gold_alpide_33_SC_120m_run1_060121.root
# hadd Source file 15: Analyzed_Data/gold_alpide_33_SC_120m_run11_060121/gold_alpide_33_SC_120m_run11_060121.root
# hadd Source file 16: Analyzed_Data/gold_alpide_33_SC_120m_run12_060121/gold_alpide_33_SC_120m_run12_060121.root
# hadd Source file 17: Analyzed_Data/gold_alpide_33_SC_120m_run2_060121/gold_alpide_33_SC_120m_run2_060121.root
# hadd Source file 18: Analyzed_Data/gold_alpide_33_SC_120m_run3_060121/gold_alpide_33_SC_120m_run3_060121.root
# hadd Source file 19: Analyzed_Data/gold_alpide_33_SC_120m_run4_060121/gold_alpide_33_SC_120m_run4_060121.root
# hadd Source file 20: Analyzed_Data/gold_alpide_33_SC_120m_run5_060121/gold_alpide_33_SC_120m_run5_060121.root
# hadd Source file 21: Analyzed_Data/gold_alpide_33_SC_120m_run6_060121/gold_alpide_33_SC_120m_run6_060121.root
# hadd Source file 22: Analyzed_Data/gold_alpide_33_SC_120m_run7_060121/gold_alpide_33_SC_120m_run7_060121.root
# hadd Source file 23: Analyzed_Data/gold_alpide_33_SC_120m_run8_060121/gold_alpide_33_SC_120m_run8_060121.root
# hadd Source file 24: Analyzed_Data/gold_alpide_33_SC_120m_run9_060121/gold_alpide_33_SC_120m_run9_060121.root
# hadd Source file 25: Analyzed_Data/gold_alpide_43_SC_240m_run10_040121/gold_alpide_43_SC_240m_run10_040121.root
# hadd Source file 26: Analyzed_Data/gold_alpide_43_SC_240m_run1_040121/gold_alpide_43_SC_240m_run1_040121.root
# hadd Source file 27: Analyzed_Data/gold_alpide_43_SC_240m_run11_040121/gold_alpide_43_SC_240m_run11_040121.root
# hadd Source file 28: Analyzed_Data/gold_alpide_43_SC_240m_run12_040121/gold_alpide_43_SC_240m_run12_040121.root
# hadd Source file 29: Analyzed_Data/gold_alpide_43_SC_240m_run2_040121/gold_alpide_43_SC_240m_run2_040121.root
# hadd Source file 30: Analyzed_Data/gold_alpide_43_SC_240m_run3_040121/gold_alpide_43_SC_240m_run3_040121.root
# hadd Source file 31: Analyzed_Data/gold_alpide_43_SC_240m_run4_040121/gold_alpide_43_SC_240m_run4_040121.root
# hadd Source file 32: Analyzed_Data/gold_alpide_43_SC_240m_run5_040121/gold_alpide_43_SC_240m_run5_040121.root
# hadd Source file 33: Analyzed_Data/gold_alpide_43_SC_240m_run6_040121/gold_alpide_43_SC_240m_run6_040121.root
# hadd Source file 34: Analyzed_Data/gold_alpide_43_SC_240m_run7_040121/gold_alpide_43_SC_240m_run7_040121.root
# hadd Source file 35: Analyzed_Data/gold_alpide_43_SC_240m_run8_040121/gold_alpide_43_SC_240m_run8_040121.root
# hadd Source file 36: Analyzed_Data/gold_alpide_43_SC_240m_run9_040121/gold_alpide_43_SC_240m_run9_040121.root
# hadd Source file 37: Analyzed_Data/gold_alpide_53_SC_240m_run10_020121/gold_alpide_53_SC_240m_run10_020121.root
# hadd Source file 38: Analyzed_Data/gold_alpide_53_SC_240m_run1_020121/gold_alpide_53_SC_240m_run1_020121.root
# hadd Source file 39: Analyzed_Data/gold_alpide_53_SC_240m_run11_020121/gold_alpide_53_SC_240m_run11_020121.root
# hadd Source file 40: Analyzed_Data/gold_alpide_53_SC_240m_run12_020121/gold_alpide_53_SC_240m_run12_020121.root
# hadd Source file 41: Analyzed_Data/gold_alpide_53_SC_240m_run2_020121/gold_alpide_53_SC_240m_run2_020121.root
# hadd Source file 42: Analyzed_Data/gold_alpide_53_SC_240m_run3_020121/gold_alpide_53_SC_240m_run3_020121.root
# hadd Source file 43: Analyzed_Data/gold_alpide_53_SC_240m_run4_020121/gold_alpide_53_SC_240m_run4_020121.root
# hadd Source file 44: Analyzed_Data/gold_alpide_53_SC_240m_run5_020121/gold_alpide_53_SC_240m_run5_020121.root
# hadd Source file 45: Analyzed_Data/gold_alpide_53_SC_240m_run6_020121/gold_alpide_53_SC_240m_run6_020121.root
# hadd Source file 46: Analyzed_Data/gold_alpide_53_SC_240m_run7_020121/gold_alpide_53_SC_240m_run7_020121.root
# hadd Source file 47: Analyzed_Data/gold_alpide_53_SC_240m_run8_020121/gold_alpide_53_SC_240m_run8_020121.root
# hadd Source file 48: Analyzed_Data/gold_alpide_53_SC_240m_run9_020121/gold_alpide_53_SC_240m_run9_020121.root
# hadd Target path: Tot_data_tree/Tot_Alide_53SC_23SC.root:/

# %%
#ROOT.enableJSVis()
ROOT.disableJSVis()

#convert the TTree in np arrays
root_file_1  =ROOT.TFile.Open("Tot_data_tree/Tot_Alide_53SC_23SC.root")
Data_tree    = root_file_1.Get("tree")
#Data_tree.Print()

Noise_points = Data_tree.AsMatrix(['Rnoise'])
Areas        = Data_tree.AsMatrix(['Rareas'])
Means        = Data_tree.AsMatrix(['Rmeanx','Rmeany'])
Theta        = Data_tree.AsMatrix(['Rtheta'])
Weight       = Data_tree.AsMatrix(['Rweight'])
Ratios       = Data_tree.AsMatrix(['Rratios'])

# %%
hm = ROOT.TH2D('hm','Hitmap',128,0,1024,64,0,512)

for coordinate in Means:
    hm.Fill(coordinate[0],coordinate[1])
    
ROOT.gStyle.SetPalette(107)
    
HC=ROOT.TCanvas()
hm.Draw('COLZ')
HC.Draw()

print(np.mean(Means[:,0]), np.mean(Means[:,1]))
# Out:
# 504.43986951189373 259.42935205378217

# %%
ar_max=int(np.amax(Areas))
nbins=int((ar_max-1))
arHist,AC=make_histo(Areas,'Area',nbins,1,ar_max)
AC.Draw()
# Out:
# Info in <TCanvas::Print>: pdf file Area_Histo.pdf has been created

# %%
ar_max=int(np.amax(Areas))
nbins=int((ar_max-1))
ArHist,AC=make_histo(Areas,'Area',nbins,1,ar_max)
AC.Draw()

r_max=(np.amax(Ratios)+0.5)
nbins=150
RHist,RC=make_histo(Ratios,'PCA_Ratio',nbins,0.5,r_max)
RC.Draw()
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: Area (Potential memory leak).
# Info in <TCanvas::Print>: pdf file Area_Histo.pdf has been created
# Info in <TCanvas::Print>: pdf file PCA_Ratio_Histo.pdf has been created

# %%
Area_thr=19
Ratio_thr=3

xmin = 10
xmax = 1013
ymin = 10 
ymax = 490


mask_thr =  np.logical_and (np.squeeze(Areas)      > Area_thr, np.squeeze(Ratios)     < Ratio_thr)
mask_x   =  np.logical_and (np.squeeze(Means[:,0]) > xmin    , np.squeeze(Means[:,0]) < xmax     )
mask_y   =  np.logical_and (np.squeeze(Means[:,1]) > ymin    , np.squeeze(Means[:,1]) < ymax     )

mask = np.logical_and(mask_thr, np.logical_and(mask_x, mask_y))


Areas_disc  = Areas [mask]
Means_disc  = Means [mask]
Theta_disc  = Theta [mask]
Weight_disc = Weight[mask]
Ratios_disc = Ratios[mask]


#A_disc_index = np.where  (Areas<Area_thr)
#Areas_disc   = np.delete (Areas ,A_disc_index)
#Means_disc   = np.delete (Means ,A_disc_index,axis=0)
#Theta_disc   = np.delete (Theta ,A_disc_index)
#Weight_disc  = np.delete (Weight,A_disc_index)
#Ratios_disc  = np.delete (Ratios,A_disc_index)

#R_disc_index=np.where (Ratios_disc>Ratio_thr)
#Areas_disc  =np.delete(Areas_disc,R_disc_index)
#Means_disc  =np.delete(Means_disc,R_disc_index,axis=0)
#Theta_disc  =np.delete(Theta_disc,R_disc_index)
#Weight_disc =np.delete(Weight_disc,R_disc_index)
#Ratios_disc =np.delete(Ratios_disc,R_disc_index)

# %%
th_max = (np.amax(Theta_disc))
th_min = (np.amin(Theta_disc))
nbins  = 50

ThHist = ROOT.TH1F('ThHist', 'Theta weighted',nbins,th_min,th_max)

alpide_data   = []
alpide_weight = []

for value,weight in zip(Theta_disc,Weight_disc):
    #ThHist.Fill(value,weight/(ALPIDE_norm[int(value*180/(np.pi)/0.9+100)]))
    ThHist.Fill(value,1/(ALPIDE_norm[int(value*180/(np.pi)/0.9+100)]))
    alpide_data.append(value*180/np.pi)
    alpide_weight.append(1/(ALPIDE_norm[int(value*180/(np.pi)/0.9+100)]))
    #ThHist.Fill(value,weight)
    
ThHist.SetStats(False)
alpide_data   = np.array(alpide_data  )
alpide_weight = np.array(alpide_weight)
    
TC = ROOT.TCanvas()

ThHist.Draw('HIST')
TC.SetLogy()
TC.Draw()
TC.Print('Graph_images/Theta_histo.png')
# Out:
# Info in <TCanvas::Print>: png file Graph_images/Theta_histo.png has been created

# %%
ar_max = int(np.amax(Areas_disc))
nbins  = int(ar_max)

ArHist,AC=make_histo(Areas_disc,'Area',nbins,1,ar_max+1)
AC.Draw()
AC.Print('Area_histo.png')

r_max   = np.amax(Ratios_disc)
nbins   = 100


RHist,RC=make_histo(Ratios_disc,'Ratios',nbins,0.95,r_max+0.05)
RHist.Draw()
RC.Draw()


#MxHist = ROOT.TH1F('MxHist', 'X Means',16,0,1023)
#
#for value in Means_disc[:,0]:
#    MxHist.Fill(value)
#
#MxC=ROOT.TCanvas()
#MxHist.Draw()
#MxC.Draw()
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: Area (Potential memory leak).
# Info in <TCanvas::Print>: pdf file Area_Histo.pdf has been created
# Info in <TCanvas::Print>: png file Area_histo.png has been created
# Info in <TCanvas::Print>: pdf file Ratios_Histo.pdf has been created

# %% [markdown]
# ## Compare with simulation

# %%
alpide_sim= np.loadtxt("../../../simulations/notebook/AlpideHistoSim.txt")
alpide_sim= alpide_sim[np.logical_and(alpide_sim[:,0]>min(alpide_data),alpide_sim[:,0]<max(alpide_data))]

norm = np.sum(alpide_sim)*(alpide_sim[1,0]-alpide_sim[0,0])

plt.hist(alpide_data, weights=alpide_weight, bins=30, density=True, label="data")
plt.scatter(alpide_sim[:,0], alpide_sim[:,1]/norm, color='red', zorder=1000, label="sim")
plt.vlines(0,0,0.2, color='yellow', zorder=10000)
plt.yscale("log")
plt.legend()

# %% [markdown]
# # THR analysis
# * Noise vs VCASN
# * Area vs PCA ratio 2D Histo

# %%
#Run packet analyzer script for all threshold
Data_folder_path="Data"
files=os.listdir(Data_folder_path+"/")
for name in files:
    if name.startswith('Data_VCASN_'):
        #analyze the data
        args = "-f "+name+" -Df "+Data_folder_path+" -d 1 10 "
        # %run 'Packet_analyzer.py' {args}

# %%
#Noise dependace on VCASN

VCASN_val    = []
Noise_points = []


files=os.listdir(Data_folder_path+"/")
for name in files:
    if name.startswith('Data_VCASN_'):
        V_CASN_THR=int(name.split('_')[2], base=16)
        VCASN_val = np.append(VCASN_val,V_CASN_THR)
        
        file=open("Data/"+name+"/Stat_"+name+".txt")
        line=file.readlines()
        for l in line:
            if (l.startswith("Readout_time")):
                time=float(l.split('=')[1].strip()[:-1])
            if (l.startswith("Strobe")):
                Strobe=int(l.split('=')[1].strip()[:-1])
            if (l.startswith("Gap")):
                Gap=int(l.split('=')[1].strip()[:-1])
        
        filename="Analyzed_Data/"+name+"/"+name+".root"
        root_file_1  = ROOT.TFile.Open(filename)
        Data_tree    = root_file_1.Get("tree")
        Noise        = Data_tree.AsMatrix(['Rnoise'])
        Noise_points = np.append(Noise_points,Noise[0]*(Strobe+Gap)/(time*Strobe))

# %%
#plt.plot(VCASN_val,Noise_points, 'bo')
Noise_graph = ROOT.TGraph(len(Noise_points),VCASN_val,Noise_points)

Noise_graph.SetMarkerColor(4)
Noise_graph.SetMarkerStyle(2)
Noise_graph.SetMarkerSize(2)
YAxis = Noise_graph.GetYaxis()
YAxis.SetRangeUser(-1000,100000)

NPC = ROOT.TCanvas()

Noise_graph.Draw('AP')
NPC.Draw()

# %%
#convert the TTree in np arrays
name        = "gold_17_DC_30m_run1_251220"
filename    = "Analyzed_Data/"+name+"/"+name+".root"
root_file = ROOT.TFile.Open(filename)
Data_tree   = root_file.Get("tree")

Areas  = Data_tree.AsMatrix(['Rareas'])
Means  = Data_tree.AsMatrix(['Rmeanx','Rmeany'])
Ratios = Data_tree.AsMatrix(['Rratios'])

# %%
ar_max=int(np.amax(Areas))
A_R_Histo = ROOT.TH2D('A_R_Histo','Area vs Ratio',ar_max-2,2,ar_max,40,0.5,10.5)

for i in range(len(Areas)):
    A_R_Histo.Fill(Areas[i],Ratios[i])
    
    
ARC=ROOT.TCanvas()
A_R_Histo.Draw("COLZ")
A_R_Histo.SetStats(False)
ARC.Draw()
