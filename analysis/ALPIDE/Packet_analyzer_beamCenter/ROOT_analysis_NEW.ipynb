# %%
import ROOT
import numpy as np
import matplotlib.pyplot as plt
import sys
import os
# Out:
# Welcome to JupyROOT 6.22/02

# %%
def make_histo(Data_array,Title,nbins,xmin,xmax,save=True):
    Histo = ROOT.TH1F(Title,Title,nbins,xmin,xmax)
    for value in Data_array:
        Histo.Fill(value)

    Canv=ROOT.TCanvas()
    Histo.Draw()
    
    if save:
        Image_name=Title + '_Histo.pdf'
        Canv.Print(Image_name)
    
    return Histo, Canv

# %%
name='gold_47_SC_90m_211220'
name.split('_')

angle=int(name.split('_')[1])*(1 if name.split('_')[2]=='DC' else -1)

file=open('gold_47_SC_90m_211220/Stat_gold_47_SC_90m_211220.txt')
line=file.readlines()
for l in line:
    if (l.startswith("Readout_time")):
        time=float(l.split('=')[1].strip()[:-1])
    if (l.startswith("Strobe")):
        Strobe=int(l.split('=')[1].strip()[:-1])
    if (l.startswith("Gap")):
        Gap=int(l.split('=')[1].strip()[:-1])
        
weight=3600*(Gap+Strobe)/(Strobe*time)

os.system("python Packet_analyzer.py -f gold_47_SC_90m_211220 -p -A DB -d 1 10 -b 1000 -s %i -w %f " % (angle,weight))
# Out:
# 0
# gold_47_SC_90m_211220: 100%|██████████| 1/1 [00:00<00:00,  2.40it/s]
# gold_47_SC_90m_211220: 100%|██████████| 1/1 [00:00<00:00,  2.47it/s]

# %% [markdown]
# # Analysis on a specific dataset

# %%
files=os.listdir()
for name in files:
    if name.startswith("gold_"):
        angle=int(name.split('_')[1])*(1 if name.split('_')[2]=='DC' else -1)

        file=open(name+"/Stat_"+name+".txt")
        line=file.readlines()
        for l in line:
            if (l.startswith("Readout_time")):
                time=float(l.split('=')[1].strip()[:-1])
            if (l.startswith("Strobe")):
                Strobe=int(l.split('=')[1].strip()[:-1])
            if (l.startswith("Gap")):
                Gap=int(l.split('=')[1].strip()[:-1])
                
        #weight that gives count/hour
        weight=3600*(Gap+Strobe)/(Strobe*time)

        os.system("python Packet_analyzer.py -f " + name + " -p -A DB -d 1 10 -b 1000 -s %i -w %f " % (angle,weight))

# %%
! $ROOTSYS/bin/hadd Tot_63_2.root Analyzed_Data/gold_*/*.root

# %% [markdown]
# # Analysis with normalization (time and Strobe parameters)

# %%
#normalization array from -180° to 180° in steps
ALPIDE_norm=np.zeros(201)

#load files of a cartain data set
files=os.listdir()
for name in files:
    if name.startswith("gold_"):
        angle=int(name.split('_')[1])*(1 if name.split('_')[2]=='DC' else -1)
        file=open(name+"/Stat_"+name+".txt")
        line=file.readlines()
        for l in line:
            if (l.startswith("Readout_time")):
                time=float(l.split('=')[1].strip()[:-1])
            if (l.startswith("Strobe")):
                Strobe=int(l.split('=')[1].strip()[:-1])
            if (l.startswith("Gap")):
                Gap=int(l.split('=')[1].strip()[:-1])
                
        #weight that gives count/hour
        weight=3600*(Gap+Strobe)/(Strobe*time)
        
        #compute the normalization parameter
        for i in range(angle-29,angle-4):
            ALPIDE_norm[100+i] += weight

        #analyze the data
        #os.system("python Packet_analyzer.py -f " + name + " -p -b 1000 -s %i -w %f" % (angle,weight))
        Args = "-f " + name + " -p -A DB -b 1000 -s %i -w %f " % (angle,weight)
        # %run 'Packet_analyzer.py' {Args}
# Out:
# usage: Packet_analyzer.py [-h] [-f N] [-p] [-A Agg or DB] [-d N [N ...]]
#                           [-s N] [-w N] [-b N]
# Packet_analyzer.py: error: argument -d/--Dist: invalid int value: '[1,10]'
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/alessandro/anaconda3/envs/pyroot/lib/python3.8/argparse.py", line 2422, in _get_value
#     result = type_func(arg_string)
# ValueError: invalid literal for int() with base 10: '[1,10]'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/alessandro/anaconda3/envs/pyroot/lib/python3.8/argparse.py", line 1800, in parse_known_args
#     namespace, args = self._parse_known_args(args, namespace)
#   File "/home/alessandro/anaconda3/envs/pyroot/lib/python3.8/argparse.py", line 2031, in _parse_known_args
#     self._get_value(action, action.default))
#   File "/home/alessandro/anaconda3/envs/pyroot/lib/python3.8/argparse.py", line 2435, in _get_value
#     raise ArgumentError(action, msg % args)
# argparse.ArgumentError: argument -d/--Dist: invalid int value: '[1,10]'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/alessandro/anaconda3/envs/pyroot/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2740, in safe_execfile
#     py3compat.execfile(
#   File "/home/alessandro/anaconda3/envs/pyroot/lib/python3.8/site-packages/IPython/utils/py3compat.py", line 168, in execfile
#     exec(compiler(f.read(), fname, 'exec'), glob, loc)
#   File "/home/alessandro/Desktop/university/RutherfordScattering_AdvLab/analysis/ALPIDE/Packet_analyzer/Packet_analyzer.py", line 152, in <module>
#     args = parser.parse_args()
#   File "/home/alessandro/anaconda3/envs/pyroot/lib/python3.8/argparse.py", line 1768, in parse_args
#     args, argv = self.parse_known_args(args, namespace)
#   File "/home/alessandro/anaconda3/envs/pyroot/lib/python3.8/argparse.py", line 1807, in parse_known_args
#     self.error(str(err))
#   File "/home/alessandro/anaconda3/envs/pyroot/lib/python3.8/argparse.py", line 2521, in error
#     self.exit(2, _('%(prog)s: error: %(message)s\n') % args)
#   File "/home/alessandro/anaconda3/envs/pyroot/lib/python3.8/argparse.py", line 2508, in exit
#     _sys.exit(status)
# SystemExit: 2
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/alessandro/anaconda3/envs/pyroot/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/alessandro/anaconda3/envs/pyroot/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/alessandro/anaconda3/envs/pyroot/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/alessandro/anaconda3/envs/pyroot/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/pyroot/lib/python3.8/argparse.py in _get_value(self, action, arg_string)
#    2421         try:
# -> 2422             result = type_func(arg_string)
#    2423
#
# ValueError: invalid literal for int() with base 10: '[1,10]'
#
# During handling of the above exception, another exception occurred:
#
# ArgumentError                             Traceback (most recent call last)
# ~/anaconda3/envs/pyroot/lib/python3.8/argparse.py in parse_known_args(self, args, namespace)
#    1799         try:
# -> 1800             namespace, args = self._parse_known_args(args, namespace)
#    1801             if hasattr(namespace, _UNRECOGNIZED_ARGS_ATTR):
#
# ~/anaconda3/envs/pyroot/lib/python3.8/argparse.py in _parse_known_args(self, arg_strings, namespace)
#    2030                         setattr(namespace, action.dest,
# -> 2031                                 self._get_value(action, action.default))
#    2032
#
# ~/anaconda3/envs/pyroot/lib/python3.8/argparse.py in _get_value(self, action, arg_string)
#    2434             msg = _('invalid %(type)s value: %(value)r')
# -> 2435             raise ArgumentError(action, msg % args)
#    2436
#
# ArgumentError: argument -d/--Dist: invalid int value: '[1,10]'
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
# ~/anaconda3/envs/pyroot/lib/python3.8/site-packages/IPython/core/interactiveshell.py in safe_execfile(self, fname, exit_ignore, raise_exceptions, shell_futures, *where)
#    2739                 glob, loc = (where + (None, ))[:2]
# -> 2740                 py3compat.execfile(
#    2741                     fname, glob, loc,
#
# ~/anaconda3/envs/pyroot/lib/python3.8/site-packages/IPython/utils/py3compat.py in execfile(fname, glob, loc, compiler)
#     167         compiler = compiler or compile
# --> 168         exec(compiler(f.read(), fname, 'exec'), glob, loc)
#     169
#
# ~/Desktop/university/RutherfordScattering_AdvLab/analysis/ALPIDE/Packet_analyzer/Packet_analyzer.py in <module>
#     151
# --> 152 args = parser.parse_args()
#     153
#
# ~/anaconda3/envs/pyroot/lib/python3.8/argparse.py in parse_args(self, args, namespace)
#    1767     def parse_args(self, args=None, namespace=None):
# -> 1768         args, argv = self.parse_known_args(args, namespace)
#    1769         if argv:
#
# ~/anaconda3/envs/pyroot/lib/python3.8/argparse.py in parse_known_args(self, args, namespace)
#    1806             err = _sys.exc_info()[1]
# -> 1807             self.error(str(err))
#    1808
#
# ~/anaconda3/envs/pyroot/lib/python3.8/argparse.py in error(self, message)
#    2520         args = {'prog': self.prog, 'message': message}
# -> 2521         self.exit(2, _('%(prog)s: error: %(message)s\n') % args)
#
# ~/anaconda3/envs/pyroot/lib/python3.8/argparse.py in exit(self, status, message)
#    2507             self._print_message(message, _sys.stderr)
# -> 2508         _sys.exit(status)
#    2509
#
# SystemExit: 2
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-46c8d3d763d0> in <module>
#      27         #os.system("python Packet_analyzer.py -f " + name + " -p -b 1000 -s %i -w %f" % (angle,weight))
#      28         Args = "-f " + name + " -p -A DB -b 1000 -s %i -w %f " % (angle,weight)
# ---> 29         get_ipython().run_line_magic('run', "'Packet_analyzer.py' {Args}")
#      30
#      31
#
# ~/anaconda3/envs/pyroot/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2325                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2326             with self.builtin_trap:
# -> 2327                 result = fn(*args, **kwargs)
#    2328             return result
#    2329
#
# <decorator-gen-52> in run(self, parameter_s, runner, file_finder)
#
# ~/anaconda3/envs/pyroot/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/anaconda3/envs/pyroot/lib/python3.8/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     834                     else:
#     835                         # regular execution
# --> 836                         run()
#     837
#     838             if 'i' in opts:
#
# ~/anaconda3/envs/pyroot/lib/python3.8/site-packages/IPython/core/magics/execution.py in run()
#     819
#     820                         def run():
# --> 821                             runner(filename, prog_ns, prog_ns,
#     822                                     exit_ignore=exit_ignore)
#     823
#
# ~/anaconda3/envs/pyroot/lib/python3.8/site-packages/IPython/core/interactiveshell.py in safe_execfile(self, fname, exit_ignore, raise_exceptions, shell_futures, *where)
#    2755                         raise
#    2756                     if not exit_ignore:
# -> 2757                         self.showtraceback(exception_only=True)
#    2758             except:
#    2759                 if raise_exceptions:
#
# ~/anaconda3/envs/pyroot/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2036                     stb = ['An exception has occurred, use %tb to see '
#    2037                            'the full traceback.\n']
# -> 2038                     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2039                                                                      value))
#    2040                 else:
#
# ~/anaconda3/envs/pyroot/lib/python3.8/site-packages/IPython/core/ultratb.py in get_exception_only(self, etype, value)
#     821         value : exception value
#     822         """
# --> 823         return ListTB.structured_traceback(self, etype, value)
#     824
#     825     def show_exception_only(self, etype, evalue):
#
# ~/anaconda3/envs/pyroot/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     696             chained_exceptions_tb_offset = 0
#     697             out_list = (
# --> 698                 self.structured_traceback(
#     699                     etype, evalue, (etb, chained_exc_ids),
#     700                     chained_exceptions_tb_offset, context)
#
# ~/anaconda3/envs/pyroot/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1434         else:
#    1435             self.tb = tb
# -> 1436         return FormattedTB.structured_traceback(
#    1437             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1438
#
# ~/anaconda3/envs/pyroot/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1334         if mode in self.verbose_modes:
#    1335             # Verbose modes need a full traceback
# -> 1336             return VerboseTB.structured_traceback(
#    1337                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1338             )
#
# ~/anaconda3/envs/pyroot/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1191         """Return a nice text document describing the traceback."""
#    1192
# -> 1193         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1194                                                                tb_offset)
#    1195
#
# ~/anaconda3/envs/pyroot/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1149
#    1150
# -> 1151         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1152
#    1153         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/anaconda3/envs/pyroot/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
#merge all the TTree
! $ROOTSYS/bin/hadd -f Tot_.root Analyzed_Data/gold_*/*.root
# Out:
# hadd Target file: Tot_63_2.root
# hadd compression setting for all output: 1
# hadd Source file 1: Analyzed_Data/gold_11_SC_150m_221220/gold_11_SC_150m_221220.root
# hadd Source file 2: Analyzed_Data/gold_13_SC_60m_221220/gold_13_SC_60m_221220.root
# hadd Source file 3: Analyzed_Data/gold_15_SC_90m_221220/gold_15_SC_90m_221220.root
# hadd Source file 4: Analyzed_Data/gold_17_SC_90m_221220/gold_17_SC_90m_221220.root
# hadd Source file 5: Analyzed_Data/gold_19_SC_90m_221220/gold_19_SC_90m_221220.root
# hadd Source file 6: Analyzed_Data/gold_21_SC_60m_221220/gold_21_SC_60m_221220.root
# hadd Source file 7: Analyzed_Data/gold_27_DC_30m_run10_231220/gold_27_DC_30m_run10_231220.root
# hadd Source file 8: Analyzed_Data/gold_27_DC_30m_run11_231220/gold_27_DC_30m_run11_231220.root
# hadd Source file 9: Analyzed_Data/gold_27_DC_30m_run1_231220/gold_27_DC_30m_run1_231220.root
# hadd Source file 10: Analyzed_Data/gold_27_DC_30m_run2_231220/gold_27_DC_30m_run2_231220.root
# hadd Source file 11: Analyzed_Data/gold_27_DC_30m_run3_231220/gold_27_DC_30m_run3_231220.root
# hadd Source file 12: Analyzed_Data/gold_27_DC_30m_run4_231220/gold_27_DC_30m_run4_231220.root
# hadd Source file 13: Analyzed_Data/gold_27_DC_30m_run5_231220/gold_27_DC_30m_run5_231220.root
# hadd Source file 14: Analyzed_Data/gold_27_DC_30m_run6_231220/gold_27_DC_30m_run6_231220.root
# hadd Source file 15: Analyzed_Data/gold_27_DC_30m_run7_231220/gold_27_DC_30m_run7_231220.root
# hadd Source file 16: Analyzed_Data/gold_27_DC_30m_run8_231220/gold_27_DC_30m_run8_231220.root
# hadd Source file 17: Analyzed_Data/gold_27_DC_30m_run9_231220/gold_27_DC_30m_run9_231220.root
# hadd Source file 18: Analyzed_Data/gold_3_SC_60m_231220/gold_3_SC_60m_231220.root
# hadd Source file 19: Analyzed_Data/gold_45_SC_90m_211220/gold_45_SC_90m_211220.root
# hadd Source file 20: Analyzed_Data/gold_47_SC_90m_211220/gold_47_SC_90m_211220.root
# hadd Source file 21: Analyzed_Data/gold_49_SC_90m_211220/gold_49_SC_90m_211220.root
# hadd Source file 22: Analyzed_Data/gold_51_SC_90m_211220/gold_51_SC_90m_211220.root
# hadd Source file 23: Analyzed_Data/gold_53_SC_90m_211220/gold_53_SC_90m_211220.root
# hadd Source file 24: Analyzed_Data/gold_59_SC_240m_201220/gold_59_SC_240m_201220.root
# hadd Source file 25: Analyzed_Data/gold_5_SC_150m_231220/gold_5_SC_150m_231220.root
# hadd Source file 26: Analyzed_Data/gold_61_SC_240m_201220/gold_61_SC_240m_201220.root
# hadd Source file 27: Analyzed_Data/gold_63_SC_90m_201220/gold_63_SC_90m_201220.root
# hadd Source file 28: Analyzed_Data/gold_7_SC_240m_231220/gold_7_SC_240m_231220.root
# hadd Source file 29: Analyzed_Data/gold_9_SC_150m_221220/gold_9_SC_150m_221220.root
# hadd Target path: Tot_63_2.root:/

# %%
#ROOT.enableJSVis()
ROOT.disableJSVis()

#convert the TTree in np arrays
root_file_1  =ROOT.TFile.Open("Tot_63_2.root")
Data_tree    = root_file_1.Get("tree")
Data_tree.Print()

Noise_points = Data_tree.AsMatrix(['Rnoise'])
Areas        = Data_tree.AsMatrix(['Rareas'])
Means        = Data_tree.AsMatrix(['Rmeanx','Rmeany'])
Theta        = Data_tree.AsMatrix(['Rtheta'])
Weight       = Data_tree.AsMatrix(['Rweight'])
Ratios       = Data_tree.AsMatrix(['Rratios'])
# Out:
# ******************************************************************************
# *Tree    :tree      : file                                                   *
# *Entries :   490715 : Total =        13794145 bytes  File  Size =    5970786 *
# *        :          : Tree compression factor =   2.31                       *
# ******************************************************************************
# *Br    0 :Rnoise    : Rnoise/F                                               *
# *Entries :   490715 : Total  Size=    1970516 bytes  File Size  =      18400 *
# *Baskets :       79 : Basket Size=      32000 bytes  Compression= 106.99     *
# *............................................................................*
# *Br    1 :Rareas    : Rareas/F                                               *
# *Entries :   490715 : Total  Size=    1970516 bytes  File Size  =     637308 *
# *Baskets :       79 : Basket Size=      32000 bytes  Compression=   3.09     *
# *............................................................................*
# *Br    2 :Rmeanx    : Rmeanx/F                                               *
# *Entries :   490715 : Total  Size=    1970516 bytes  File Size  =    1457964 *
# *Baskets :       79 : Basket Size=      32000 bytes  Compression=   1.35     *
# *............................................................................*
# *Br    3 :Rmeany    : Rmeany/F                                               *
# *Entries :   490715 : Total  Size=    1970516 bytes  File Size  =    1414610 *
# *Baskets :       79 : Basket Size=      32000 bytes  Compression=   1.39     *
# *............................................................................*
# *Br    4 :Rtheta    : Rtheta/F                                               *
# *Entries :   490715 : Total  Size=    1970516 bytes  File Size  =    1635473 *
# *Baskets :       79 : Basket Size=      32000 bytes  Compression=   1.20     *
# *............................................................................*
# *Br    5 :Rweight   : Rweight/F                                              *
# *Entries :   490715 : Total  Size=    1970599 bytes  File Size  =      18502 *
# *Baskets :       79 : Basket Size=      32000 bytes  Compression= 106.41     *
# *............................................................................*
# *Br    6 :Rratios   : Rratios/F                                              *
# *Entries :   490715 : Total  Size=    1970599 bytes  File Size  =     783881 *
# *Baskets :       79 : Basket Size=      32000 bytes  Compression=   2.51     *
# *............................................................................*

# %%
hm = ROOT.TH2D('hm','Hitmap',128,0,1024,64,0,512)

for coordinate in Means:
    hm.Fill(coordinate[0],coordinate[1])
    
ROOT.gStyle.SetPalette(107)
    
HC=ROOT.TCanvas()
hm.Draw('COLZ')
HC.Draw()

# %%
ar_max=int(np.amax(Areas))
nbins=int((ar_max-1))
arHist,AC=make_histo(Areas,'Area',nbins,1,ar_max)
AC.Draw()
# Out:
# Info in <TCanvas::Print>: pdf file Area_Histo.pdf has been created

# %%
ar_max=int(np.amax(Areas))
nbins=int((ar_max-1))
ArHist,AC=make_histo(Areas,'Area',nbins,1,ar_max)
AC.Draw()

r_max=(np.amax(Ratios)+0.5)
nbins=150
RHist,RC=make_histo(Ratios,'PCA_Ratio',nbins,0.5,r_max)
RC.Draw()
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: Area (Potential memory leak).
# Info in <TCanvas::Print>: pdf file Area_Histo.pdf has been created
# Warning in <TFile::Append>: Replacing existing TH1: PCA_Ratio (Potential memory leak).
# Info in <TCanvas::Print>: pdf file PCA_Ratio_Histo.pdf has been created

# %%
Area_thr=14
Ratio_thr=1.81

xmin = 10
xmax = 1013
ymin = 10 
ymax = 490


mask_thr =  np.logical_and (np.squeeze(Areas)      > Area_thr, np.squeeze(Ratios)     < Ratio_thr)
mask_x   =  np.logical_and (np.squeeze(Means[:,0]) > xmin    , np.squeeze(Means[:,0]) < xmax     )
mask_y   =  np.logical_and (np.squeeze(Means[:,1]) > ymin    , np.squeeze(Means[:,1]) < ymax     )

mask = np.logical_and(mask_thr, np.logical_and(mask_x, mask_y))


Areas_disc  = Areas [mask]
Means_disc  = Means [mask]
Theta_disc  = Theta [mask]
Weight_disc = Weight[mask]
Ratios_disc = Ratios[mask]


#A_disc_index = np.where  (Areas<Area_thr)
#Areas_disc   = np.delete (Areas ,A_disc_index)
#Means_disc   = np.delete (Means ,A_disc_index,axis=0)
#Theta_disc   = np.delete (Theta ,A_disc_index)
#Weight_disc  = np.delete (Weight,A_disc_index)
#Ratios_disc  = np.delete (Ratios,A_disc_index)

#R_disc_index=np.where (Ratios_disc>Ratio_thr)
#Areas_disc  =np.delete(Areas_disc,R_disc_index)
#Means_disc  =np.delete(Means_disc,R_disc_index,axis=0)
#Theta_disc  =np.delete(Theta_disc,R_disc_index)
#Weight_disc =np.delete(Weight_disc,R_disc_index)
#Ratios_disc =np.delete(Ratios_disc,R_disc_index)

# %%
th_max = (np.amax(Theta_disc))
th_min = (np.amin(Theta_disc))
nbins  = 50

ThHist = ROOT.TH1F('ThHist', 'Theta weighted',nbins,th_min,th_max)

for value,weight in zip(Theta_disc,Weight_disc):
    ThHist.Fill(value,weight/(ALPIDE_norm[int(value*180/(np.pi)/0.9+100)]))
    #ThHist.Fill(value,weight)
    
ThHist.SetStats(False)
    
TC = ROOT.TCanvas()

ThHist.Draw('HIST')
TC.SetLogy()
TC.Draw()
TC.Print('Theta_histo.png')
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: ThHist (Potential memory leak).
# Info in <TCanvas::Print>: png file Theta_histo.png has been created

# %%
ar_max = int(np.amax(Areas_disc))
nbins  = int(ar_max)

ArHist,AC=make_histo(Areas_disc,'Area',nbins,1,ar_max+1)
AC.Draw()
AC.Print('Area_histo.png')

r_max   = np.amax(Ratios_disc)
nbins   = 100


RHist,RC=make_histo(Ratios_disc,'Ratios',nbins,0.95,r_max+0.05)
RHist.Draw()
RC.Draw()


#MxHist = ROOT.TH1F('MxHist', 'X Means',16,0,1023)
#
#for value in Means_disc[:,0]:
#    MxHist.Fill(value)
#
#MxC=ROOT.TCanvas()
#MxHist.Draw()
#MxC.Draw()
# Out:
# 43
# 1.97959303855896
# Warning in <TFile::Append>: Replacing existing TH1: Area (Potential memory leak).
# Info in <TCanvas::Print>: pdf file Area_Histo.pdf has been created
# Info in <TCanvas::Print>: png file Area_histo.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: Ratios (Potential memory leak).
# Info in <TCanvas::Print>: pdf file Ratios_Histo.pdf has been created

# %% [markdown]
# # THR analysis
# * Noise vs VCASN
# * Area vs PCA ratio 2D Histo

# %%
#Run packet analyzer script for all threshold
files=os.listdir()
for name in files:
    if name.startswith('Data_VCASN_'):
        #analyze the data
        args = "-f " + name + " -d 1 10 "
        # %run 'Packet_analyzer.py' {args}
# Out:
# Data_VCASN_41: 100%|██████████| 2/2 [00:31<00:00, 15.84s/it]
# Data_VCASN_30: 100%|██████████| 1/1 [00:09<00:00,  9.82s/it]
# Data_VCASN_3D: 100%|██████████| 1/1 [00:05<00:00,  5.10s/it]
# Data_VCASN_35: 100%|██████████| 1/1 [00:04<00:00,  4.65s/it]
# Data_VCASN_3E: 100%|██████████| 1/1 [00:14<00:00, 14.74s/it]
# Data_VCASN_39: 100%|██████████| 1/1 [00:04<00:00,  4.69s/it]
# Data_VCASN_29: 100%|██████████| 1/1 [00:04<00:00,  4.22s/it]
# Data_VCASN_2D: 100%|██████████| 1/1 [00:04<00:00,  4.45s/it]
# Data_VCASN_31: 100%|██████████| 1/1 [00:04<00:00,  4.59s/it]
# Data_VCASN_49: 100%|██████████| 2/2 [00:38<00:00, 19.45s/it]
# Data_VCASN_45: 100%|██████████| 2/2 [00:47<00:00, 23.71s/it]

# %%
#Noise dependace on VCASN

VCASN_val    = []
Noise_points = []


files=os.listdir()
for name in files:
    if name.startswith('Data_VCASN_'):
        V_CASN_THR=int(name.split('_')[2], base=16)
        VCASN_val = np.append(VCASN_val,V_CASN_THR)
        
        file=open(name+"/Stat_"+name+".txt")
        line=file.readlines()
        for l in line:
            if (l.startswith("Readout_time")):
                time=float(l.split('=')[1].strip()[:-1])
            if (l.startswith("Strobe")):
                Strobe=int(l.split('=')[1].strip()[:-1])
            if (l.startswith("Gap")):
                Gap=int(l.split('=')[1].strip()[:-1])
        
        filename="Analyzed_Data/"+name+"/"+name+".root"
        root_file_1  = ROOT.TFile.Open(filename)
        Data_tree    = root_file_1.Get("tree")
        Noise        = Data_tree.AsMatrix(['Rnoise'])
        Noise_points = np.append(Noise_points,Noise[0]*(Strobe+Gap)/(time*Strobe))

# %%
#plt.plot(VCASN_val,Noise_points, 'bo')
Noise_graph = ROOT.TGraph(len(Noise_points),VCASN_val,Noise_points)

Noise_graph.SetMarkerColor(4)
Noise_graph.SetMarkerStyle(2)
Noise_graph.SetMarkerSize(2)
YAxis = Noise_graph.GetYaxis()
YAxis.SetRangeUser(-1000,100000)

NPC         = ROOT.TCanvas()

Noise_graph.Draw('AP')
NPC.Draw()

# %%
#convert the TTree in np arrays
name        = "VC"
filename    = "Analyzed_Data/"+name+"/"+name+".root"
root_file = ROOT.TFile.Open(filename)
Data_tree   = root_file.Get("tree")

Areas  = Data_tree.AsMatrix(['Rareas'])
Means  = Data_tree.AsMatrix(['Rmeanx','Rmeany'])
Ratios = Data_tree.AsMatrix(['Rratios'])

# %%
ar_max=int(np.amax(Areas))
A_R_Histo = ROOT.TH2D('A_R_Histo','Area vs Ratio',ar_max-2,2,ar_max,40,0.5,10.5)

for i in range(len(Areas)):
    A_R_Histo.Fill(Areas[i],Ratios[i])
    
    
ARC=ROOT.TCanvas()
A_R_Histo.Draw("COLZ")
A_R_Histo.SetStats(False)
ARC.Draw()
