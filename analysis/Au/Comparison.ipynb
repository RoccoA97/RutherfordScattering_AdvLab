# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("data_proc_Au.txt")
sim  = np.loadtxt("../../simulations/notebook/simData.txt")

# %%
plt.plot(data[:,1], data[:,2]/np.max(data[:,2]), 'o') #column 0 angle in rad, 1 angle in deg, 2 number of evs
plt.plot( sim[:,0],  sim[:,1]/np.max(sim [:,1]))
plt.xlim(-25,25)
plt.yscale('log')
