# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pico_simu  = np.loadtxt("../simulations/notebook/PicoHistoSim.txt")
pico_data = np.loadtxt("PicoHistoData.txt")
pico_data[:,0] =pico_data[:,0]*0.9

pico_simu = pico_simu[np.logical_and(pico_simu[:,0] > -30, pico_simu[:,0] < 30)]
pico_data = pico_data[np.logical_and(pico_data[:,0] > -30, pico_data[:,0] < 30)]

# %%
pico_data
# Out:
# array([[-2.70000000e+01,  1.00220142e+01],
#        [-2.52000000e+01,  1.56675914e+01],
#        [-2.34000000e+01,  1.69797395e+01],
#        [-2.16000000e+01,  2.38080367e+01],
#        [-1.98000000e+01,  2.75857485e+01],
#        [-1.80000000e+01,  5.67369180e+01],
#        [-1.62000000e+01,  1.05891413e+02],
#        [-1.44000000e+01,  5.00460019e+02],
#        [-1.26000000e+01,  4.53862193e+03],
#        [-1.08000000e+01,  1.29783154e+04],
#        [-9.00000000e+00,  2.35826406e+04],
#        [-7.20000000e+00,  3.39737647e+04],
#        [-5.40000000e+00,  4.47092154e+04],
#        [-3.60000000e+00,  5.36392758e+04],
#        [-1.80000000e+00,  6.11832847e+04],
#        [ 0.00000000e+00,  6.35656068e+04],
#        [ 1.80000000e+00,  6.09102014e+04],
#        [ 3.60000000e+00,  5.32015512e+04],
#        [ 5.40000000e+00,  4.29479852e+04],
#        [ 7.20000000e+00,  3.25960548e+04],
#        [ 9.00000000e+00,  2.20641458e+04],
#        [ 1.08000000e+01,  1.29300662e+04],
#        [ 1.26000000e+01,  4.06311594e+03],
#        [ 1.44000000e+01,  5.14492179e+02],
#        [ 1.62000000e+01,  9.81949852e+01],
#        [ 1.80000000e+01,  4.57937779e+01],
#        [ 1.98000000e+01,  2.65375174e+01],
#        [ 2.16000000e+01,  2.39588042e+01],
#        [ 2.34000000e+01,  2.05125482e+01],
#        [ 2.52000000e+01,  1.31319411e+01],
#        [ 2.70000000e+01,  7.68081929e+00]])

# %%
norm_simu = np.sum(pico_simu)*(pico_simu[1,0]-pico_simu[0,0])
norm_data = np.sum(pico_data)*(pico_data[1,0]-pico_data[0,0])

# %%
plt.plot(pico_simu[:,0], pico_simu[:,1]/norm_simu, color='red',  label="sim")
plt.yscale("log")
plt.legend()
plt.show()

plt.plot(pico_data[:,0], pico_data[:,1]/norm_data, color='blue', label="data")
plt.yscale("log")
plt.legend()
plt.show()

plt.plot(pico_simu[:,0], pico_simu[:,1]/norm_simu, color='red',  label="sim")
plt.plot(pico_data[:,0], pico_data[:,1]/norm_data, color='blue', label="data")
plt.yscale("log")
plt.legend()
plt.show()
